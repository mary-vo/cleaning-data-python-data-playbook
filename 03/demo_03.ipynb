# %% [markdown]
# # Dropping Columns

# %%
import pandas as pd
import os

sample_path = os.path.join('..','artwork_sample.csv')
data_path = os.path.join('..','artwork_data.csv')

# %%
data = pd.read_csv(sample_path)

# %%
# drop index/row is the default, this will drop the first row
data.drop(0)

# drop column
data.drop('id',axis=1)
# Out:
#   accession_number          artist artistRole  artistId  \
# 0           A00001   Blake, Robert     artist        38
# 1           A00002   Blake, Robert     artist        38
# 2           A00003   Blake, Robert     artist        38
# 3           A00004   Blake, Robert     artist        38
# 4           A00005  Blake, William     artist        39
# 5           A00006  Blake, William     artist        39
# 6           A00007  Blake, William     artist        39
# 7           A00008  Blake, William     artist        39
# 8           A00009  Blake, William     artist        39
# 9           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# ...

# %%
data.drop(columns=['height','width','depth'])
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# ...

# %%
data.drop(labels=[0,1,2])
# Out:
#      id accession_number          artist artistRole  artistId  \
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
# 5      Ciampolo the Barrator Tormented by the Devils  1826–7, reprinted 1892
# 6                        The Baffled Devils Fighting  1826–7, reprinted 1892
# 7  The Six-Footed Serpent Attacking Agnolo Brunel...  1826–7, reprinted 1892
# ...

# %%
# Even with each drop method, if we look at the dataframe, nothing has been dropped
# must pass inplace = True
data.drop(columns=['id'], inplace=True)
data
# Out:
#   accession_number          artist artistRole  artistId  \
# 0           A00001   Blake, Robert     artist        38
# 1           A00002   Blake, Robert     artist        38
# 2           A00003   Blake, Robert     artist        38
# 3           A00004   Blake, Robert     artist        38
# 4           A00005  Blake, William     artist        39
# 5           A00006  Blake, William     artist        39
# 6           A00007  Blake, William     artist        39
# 7           A00008  Blake, William     artist        39
# 8           A00009  Blake, William     artist        39
# 9           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# ...

# %%
# There is a way to never import certain columns 
data = pd.read_csv(sample_path, usecols=['artist','title'])
data
# Out:
#            artist                                              title
# 0   Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1   Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 2   Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 3   Blake, Robert     Six Drawings of Figures with Outstretched Arms
# 4  Blake, William  The Circle of the Lustful: Francesca da Rimini...
# 5  Blake, William      Ciampolo the Barrator Tormented by the Devils
# 6  Blake, William                        The Baffled Devils Fighting
# 7  Blake, William  The Six-Footed Serpent Attacking Agnolo Brunel...
# 8  Blake, William                 The Serpent Attacking Buoso Donati
# 9  Blake, William                 The Pit of Disease: The Falsifiers

# %% [markdown]
# # Changing Column Casing

# %%
import pandas as pd

# %%
data = pd.read_csv(sample_path)

# %%
data.columns
# Out:
# Index(['id', 'accession_number', 'artist', 'artistRole', 'artistId', 'title',
#        'dateText', 'medium', 'creditLine', 'year', 'acquisitionYear',
#        'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
#        'thumbnailCopyright', 'thumbnailUrl', 'url'],
#       dtype='object')

# %%
# change all column header to lower case
data.columns.str.lower()
# Out:
# ['id',
#  'accession_number',
#  'artist',
#  'artistrole',
#  'artistid',
#  'title',
#  'datetext',
#  'medium',
#  'creditline',
#  'year',
#  'acquisitionyear',
#  'dimensions',
#  'width',
#  'height',
#  'depth',
#  'units',
#  'inscription',
#  'thumbnailcopyright',
#  'thumbnailurl',
#  'url']

# %%
# for in completion to call lower on every column
# BUT this option does not change the original dataframe
# set columns to new array
[x.lower() for x in data.columns]
data.columns = [x.lower() for x in data.columns]
data
# Out:
#      id accession_number          artist artistrole  artistid  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                datetext  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# ...

# %%
data = pd.read_csv(sample_path)

# %%
# Can use map instead of for in completion 
data.columns = map(lambda x: x.lower(), data.columns)
data.columns
# Out:
# Index(['id', 'accession_number', 'artist', 'artistrole', 'artistid', 'title',
#        'datetext', 'medium', 'creditline', 'year', 'acquisitionyear',
#        'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
#        'thumbnailcopyright', 'thumbnailurl', 'url'],
#       dtype='object')

# %%
# Other things to do with map function or for in method
data = pd.read_csv(sample_path)

import re
# look for updatecase, add underscore, make the rest of the letters lower case for all columns
data.columns = [re.sub(r'([A-Z])',r'_\1', x).lower() for x in data.columns]
data.columns
# Out:
# Index(['id', 'accession_number', 'artist', 'artist_role', 'artist_id', 'title',
#        'date_text', 'medium', 'credit_line', 'year', 'acquisition_year',
#        'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
#        'thumbnail_copyright', 'thumbnail_url', 'url'],
#       dtype='object')

# %% [markdown]
# # Renaming Columns

# %%
import pandas as pd

# %%
data = pd.read_csv(sample_path)

# %%
# ONe way to rename column, remember to include inplace=True, if you want the rename to stick
# Because rename method returns a new dataframe
# Otherwise .head() at the end of the statement will let you preview the change
data.rename(columns={"thumbnailUrl":"thumbnail"})
data

# %%
data.rename({"thumbnailUrl":"thumbnail"}, axis=1)

# %%
# pass through a function for columns, this will allow us to rename all columns
data.rename(columns = lambda x: x.lower(), inplace=True)
data.columns
# Out:
# Index(['id', 'accession_number', 'artist', 'artistrole', 'artistid', 'title',
#        'datetext', 'medium', 'creditline', 'year', 'acquisitionyear',
#        'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
#        'thumbnailcopyright', 'thumbnailurl', 'url'],
#       dtype='object')

# %%
# You can also rename columns by grabbing the array of column names and changing the names direcrtly
data.columns = ['id', 'AccessionNumber', 'Artist', 'Artistrole', 'artistid', 'title',
       'datetext', 'medium', 'creditline', 'year', 'acquisitionyear',
       'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
       'thumbnailcopyright', 'thumbnailurl', 'url']

# %%
data.columns
# Out:
# Index(['id', 'AccessionNumber', 'Artist', 'Artistrole', 'artistid', 'title',
#        'datetext', 'medium', 'creditline', 'year', 'acquisitionyear',
#        'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
#        'thumbnailcopyright', 'thumbnailurl', 'url'],
#       dtype='object')

# %%
# We can set the column name with the array when reading in csv
data = pd.read_csv(sample_path, names=['id', 'AccessionNumber', 'Artist', 'Artistrole', 'artistid', 'title',
       'datetext', 'medium', 'creditline', 'year', 'acquisitionyear',
       'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
       'thumbnailcopyright', 'thumbnailurl', 'url'], header=0)

"""reason for header=0 is because if you're settig the names of the headers, pandas thinks that the csv does not have headers of its own"""

# %%
data.columns
# Out:
# Index(['id', 'AccessionNumber', 'Artist', 'Artistrole', 'artistid', 'title',
#        'datetext', 'medium', 'creditline', 'year', 'acquisitionyear',
#        'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
#        'thumbnailcopyright', 'thumbnailurl', 'url'],
#       dtype='object')
